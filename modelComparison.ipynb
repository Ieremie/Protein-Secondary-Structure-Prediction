# %%
import pickle 
import os
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'C:\\Users\\Ieremie\\Documents\\Individual project\\secondSemester\\Personal-Project': ['.git', '.ipynb_checkpoints', '699-Guilermo-Dropout-0.5.hdf5', '70027-Guilermo-Dropout-0.6.hdf5', 'casp12', 'dataset.ipynb', 'datasetTranskay', 'Different depth.png', 'experimentsData', 'kfold', 'modelComparison.ipynb', 'munge-newdata.ipynb', 'newExperiments', 'oldModels.py', 'plotsForReport.ipynb', 'pozeReport', 'proteinNetParser.ipynb', 'proteinPrediction.ipynb', 'secondary_proteins_prediction']

# %%
m1H = pickle.load( open( "mLayer1", "rb" ) )
m3H = pickle.load( open( "mLayer3", "rb" ) )
m5H = pickle.load( open( "mLayer5", "rb" ) )
m7H = pickle.load( open( "mLayer7", "rb" ) )
m9H = pickle.load( open( "mLayer9", "rb" ) )
m11H = pickle.load( open( "mLayer11", "rb" ) )

# %%
# Plot training & validation accuracy values
plt.plot(m1H['accuracy'])
plt.plot(m1H['val_accuracy'])

plt.plot(m3H['accuracy'])
plt.plot(m3H['val_accuracy'])

plt.plot(m5H['accuracy'])
plt.plot(m5H['val_accuracy'])

plt.plot(m7H['accuracy'])
plt.plot(m7H['val_accuracy'])

plt.plot(m9H['accuracy'])
plt.plot(m9H['val_accuracy'])

plt.plot(m11H['accuracy'])
plt.plot(m11H['val_accuracy'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5c2d355748ba> in <module>
#       2
#       3 # Plot training & validation accuracy values
# ----> 4 plt.plot(m1H['accuracy'])
#       5 plt.plot(m1H['val_accuracy'])
#       6
#
# NameError: name 'm1H' is not defined

# %%
# Plot training & validation loss values

plt.plot(m1H['loss'])
plt.plot(m1H['val_loss'])

plt.plot(m3H['loss'])
plt.plot(m3H['val_loss'])

plt.plot(m5H['loss'])
plt.plot(m5H['val_loss'])

plt.plot(m7H['loss'])
plt.plot(m7H['val_loss'])

plt.plot(m9H['loss'])
plt.plot(m9H['val_loss'])

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
#plt.savefig(lossName)
plt.show()

# %%
m1H1 = pickle.load( open( "mLayer1.1", "rb" ) )
m3H1 = pickle.load( open( "mLayer3.2", "rb" ) )
m5H1 = pickle.load( open( "mLayer5.2", "rb" ) )
m7H1 = pickle.load( open( "mLayer7.2", "rb" ) )
m9H1 = pickle.load( open( "mLayer9.2", "rb" ) )
m11H1 = pickle.load( open( "mLayer11.2", "rb" ) )

# %%
# Plot training & validation accuracy values
plt.plot(m1H1['accuracy'])
plt.plot(m1H1['val_accuracy'])


plt.plot(m3H1['accuracy'])
plt.plot(m3H1['val_accuracy'])


plt.plot(m5H1['accuracy'])
plt.plot(m5H1['val_accuracy'])

plt.plot(m7H1['accuracy'])
plt.plot(m7H1['val_accuracy'])

plt.plot(m9H1['accuracy'])
plt.plot(m9H1['val_accuracy'])

plt.plot(m11H1['accuracy'])
plt.plot(m11H1['val_accuracy'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
m= pickle.load( open( "true arhitecture/3-5-7", "rb" ) )#

# %%
plt.plot(m1H['accuracy'])
plt.plot(m1H['val_accuracy'])

# %%
m1H = pickle.load( open( "kfold/kfold-pssmQ8/model_history_kfold1", "rb" ) )
m3H = pickle.load( open("newExperiments/depthExplor/model_history_3", "rb" ) )
m5H = pickle.load( open( "newExperiments/depthExplor/model_history_5", "rb" ) )
m7H = pickle.load( open( "newExperiments/depthExplor/model_history_7", "rb" ) )
m9H = pickle.load( open( "newExperiments/depthExplor/model_history_9", "rb" ) )

m1s = pickle.load( open( "newExperiments/depthExplor/model_scores_1", "rb" ) )
m3s = pickle.load( open("newExperiments/depthExplor/model_scores_3", "rb" ) )
m5s = pickle.load( open( "newExperiments/depthExplor/model_scores_5", "rb" ) )
m7s = pickle.load( open( "newExperiments/depthExplor/model_scores_7", "rb" ) )
m9s = pickle.load( open( "newExperiments/depthExplor/model_scores_9", "rb" ) )

# %%
accuracyName = 'accuracyMiddlewindowQ2W19Model2.png'
lossName = 'lossMiddlewindowQ2W19Model2.png'

# Plot training & validation accuracy values
plt.plot(m1H['acc'])
plt.plot(m1H['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
#plt.savefig(accuracyName)
plt.show()


# Plot training & validation loss values
plt.plot(m1H['loss'])
plt.plot(m1H['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
#plt.savefig(lossName)
plt.show()

# %%
fig = plt.figure()

gs = gridspec.GridSpec(1, 3, wspace=0.2, width_ratios=[7,3,1])
fig.set_size_inches(12, 7)

ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[2])
ax2 = fig.add_subplot(gs[1])

   

ax0.set_ylabel("Q8 Training Accuracy", fontsize=16, labelpad=25, weight='bold')
ax0.set_xlabel("Epochs",  fontsize=16, weight='bold')

ax1.yaxis.set_label_position("right")
ax1.set_ylabel(" Q8 Accuracy on CB513",fontsize=16,labelpad=25, weight='bold')

ax2.set_xlabel('Validation', fontsize=13, weight='bold')

ax0.tick_params(labelsize=12)
ax1.tick_params(labelsize=12)


ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax1.spines['right'].set_visible(False)


ax1.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)


ticks = [0.65,0.66,0.67,0.68,0.69,0.70,0.71,0.72,0.73,0.74,0.75]    
#plt.yticks(ticks)
#ax0.set_yticks(ticks)
#ax1.set_yticks(ticks)
ax2.set_xticks([0,2,4,6,8,10])
    
# Plot training & validation accuracy values

#ratio fix
ax0.plot(ticks, color = 'w')
ax1.plot(ticks, color = 'w')
ax2.plot(ticks, color = 'w')

ax0.plot(m1H['accuracy'], color='r', label="1 layer", linewidth=3)
ax2.plot(m1H['val_accuracy'],color='r')

ax0.plot(m3H['acc'], color='b', label="3 layer", linewidth=3)
ax2.plot(m3H['val_acc'], color='b')


ax0.plot(m5H['acc'], color='orange', label="5 layer", linewidth=3)
ax2.plot(m5H['val_acc'], color='orange')

ax0.plot(m7H['acc'], color='g', label="7 layer", linewidth=3)
ax2.plot(m7H['val_acc'], color='g')

ax0.plot(m9H['acc'],  color='violet', label="9 layer", linewidth=3)
ax2.plot(m9H['val_acc'],  color='violet')


ax1.plot(1,m1s[1],marker='v', color='r', ls='-',markersize=10)
ax1.plot(2,m3s[1],marker='v', color='b', ls='',markersize=10)
ax1.plot(3,m5s[1],marker='v', color='orange', ls='',markersize=10)
ax1.plot(4,m7s[1],marker='v', color='g', ls='',markersize=10)
ax1.plot(5,m9s[1],marker='v', color='violet',markersize=10)

res = 0.65
for i in range(10):
    ax0.axhline(y=res, c = "black", linewidth=0.2)
    ax1.axhline(y=res, c = "black", linewidth=0.2)
    ax2.axhline(y=res, c = "black", linewidth=0.2)
    res += 0.01
 
 #legend(loc="upper left")
legend = ax0.legend( title="64 NEURONS per layer", loc=0, fontsize='large', fancybox=True)

plt.savefig("Different depth", bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
from keras.models import load_model
from sklearn.model_selection import KFold
from time import time
from timeit import default_timer as timer
import pickle


model = load_model('newExperiments/depthExplor/model_1.h5')
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# InputWindow (InputLayer)     (None, 19, 21)            0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 19, 64)            4096
# _________________________________________________________________
# BN1 (BatchNormalization)     (None, 19, 64)            256
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1216)              0
# _________________________________________________________________
# last (Dense)                 (None, 16)                19472
# _________________________________________________________________
# BN10 (BatchNormalization)    (None, 16)                64
# _________________________________________________________________
# softmax (Dense)              (None, 8)                 136
# ...

# %%
import matplotlib.gridspec as gridspec
fig = plt.figure()
gs = gridspec.GridSpec(3, 1, height_ratios=[20, 1, 1], wspace=1, hspace=.2)
fig.set_size_inches(10, 9.8)


ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[1])
ax2 = fig.add_subplot(gs[2])

ax0.spines['right'].set_visible(False)
ax0.get_xaxis().set_visible(False)
ax0.axhline(y=50, c = "black", linewidth=1.5)
ax0.set_yticks([0,50,100])
ax0.axis([1,gen, 0, 100])

ax0.tick_params(labelsize=17)
ax1.tick_params(labelsize=17)
ax2.tick_params(labelsize=17)

ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.get_xaxis().set_visible(False)
ax1.axis([1,gen, 0,1])

ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.axis([1,gen, 0,1])

# %%
m1H = pickle.load( open( "newExperiments/depthExplor/model_history_11", "rb" ) )
m3H = pickle.load( open("newExperiments/depthExplor/model_history_33", "rb" ) )
m5H = pickle.load( open( "newExperiments/depthExplor/model_history_55", "rb" ) )
m7H = pickle.load( open( "newExperiments/depthExplor/model_history_77", "rb" ) )
m9H = pickle.load( open( "newExperiments/depthExplor/model_history_9", "rb" ) )

m1s = pickle.load( open( "newExperiments/depthExplor/model_scores_11", "rb" ) )
m3s = pickle.load( open("newExperiments/depthExplor/model_scores_33", "rb" ) )
m5s = pickle.load( open( "newExperiments/depthExplor/model_scores_55", "rb" ) )
m7s = pickle.load( open( "newExperiments/depthExplor/model_scores_77", "rb" ) )
m9s = pickle.load( open( "newExperiments/depthExplor/model_scores_9", "rb" ) )

# %%
fig = plt.figure()

gs = gridspec.GridSpec(1, 3, wspace=0.2, width_ratios=[7,3,1])
fig.set_size_inches(12, 7)

ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[2])
ax2 = fig.add_subplot(gs[1])

   

ax0.set_ylabel("Q8 Training Accuracy", fontsize=16, labelpad=25, weight='bold')
ax0.set_xlabel("Epochs",  fontsize=16, weight='bold')

ax1.yaxis.set_label_position("right")
ax1.set_ylabel(" Q8 Accuracy on CB513",fontsize=16,labelpad=25, weight='bold')

ax2.set_xlabel('Validation', fontsize=13,weight='bold')

ax0.tick_params(labelsize=12)
ax1.tick_params(labelsize=12)


ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax1.spines['right'].set_visible(False)


ax1.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)
ax2.set_xticks([0,2,4,6,8,10])

ticks = [0.66,0.67,0.68,0.69,0.70,0.71,0.72,0.73,0.74,0.75]    
#plt.yticks(ticks)
#ax0.set_yticks(ticks)
#ax1.set_yticks(ticks)
#ax2.set_yticks(ticks)
    
# Plot training & validation accuracy values

#ratio fix
ax0.plot(ticks, color = 'w')
ax1.plot(ticks, color = 'w')
ax2.plot(ticks, color = 'w')

ax0.plot(m1H['acc'], color='r', label="1 layer", linewidth=3)
ax2.plot(m1H['val_acc'],color='r')

ax0.plot(m3H['acc'], color='b', label="3 layer", linewidth=3)
ax2.plot(m3H['val_acc'], color='b')


ax0.plot(m5H['acc'], color='orange', label="5 layer", linewidth=3)
ax2.plot(m5H['val_acc'], color='orange')

ax0.plot(m7H['acc'], color='g', label="7 layer", linewidth=3)
ax2.plot(m7H['val_acc'], color='g')

ax0.plot(m9H['acc'],  color='violet', label="9 layer", linewidth=3)
ax2.plot(m9H['val_acc'],  color='violet')


ax1.plot(1,m1s[1],marker='v', color='r', ls='-',markersize=10)
ax1.plot(2,m3s[1],marker='v', color='b', ls='',markersize=10)
ax1.plot(3,m5s[1],marker='v', color='orange', ls='',markersize=10)
ax1.plot(4,m7s[1],marker='v', color='g', ls='',markersize=10)
ax1.plot(5,m9s[1],marker='v', color='violet',markersize=10)

res = 0.66
for i in range(9):
    ax0.axhline(y=res, c = "black", linewidth=0.2)
    ax1.axhline(y=res, c = "black", linewidth=0.2)
    ax2.axhline(y=res, c = "black", linewidth=0.2)
    res += 0.01
 
 #legend(loc="upper left")
legend = ax0.legend( title="~125K parameters per network", loc=0, fontsize='large', fancybox=True)
plt.savefig("Different depth same param", bbox_inches = 'tight')
plt.show()

# %%
m5_8 = pickle.load( open( "newExperiments/depthExplor/model_history_58", "rb" ) )
m5_16 = pickle.load( open("newExperiments/depthExplor/model_history_516", "rb" ) )
m5_32 = pickle.load( open( "newExperiments/depthExplor/model_history_532", "rb" ) )
m5_64 = pickle.load( open( "newExperiments/depthExplor/model_history_5", "rb" ) )


m5_8s = pickle.load( open( "newExperiments/depthExplor/model_scores_58", "rb" ) )
m5_16s = pickle.load( open("newExperiments/depthExplor/model_scores_516", "rb" ) )
m5_32s = pickle.load( open( "newExperiments/depthExplor/model_scores_532", "rb" ) )
m5_64s = pickle.load( open( "newExperiments/depthExplor/model_scores_5", "rb" ) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97ebd125b350> in <module>
# ----> 1 m5_8 = pickle.load( open( "newExperiments/depthExplor/model_history_58", "rb" ) )
#       2 m5_16 = pickle.load( open("newExperiments/depthExplor/model_history_516", "rb" ) )
#       3 m5_32 = pickle.load( open( "newExperiments/depthExplor/model_history_532", "rb" ) )
#       4 m5_64 = pickle.load( open( "newExperiments/depthExplor/model_history_5", "rb" ) )
#       5
#
# NameError: name 'pickle' is not defined

# %%
fig = plt.figure()
gs = gridspec.GridSpec(1, 3, wspace=0.2, width_ratios=[7,3,1])
fig.set_size_inches(12, 7)

ax0 = fig.add_subplot(gs[0])
ax1 = fig.add_subplot(gs[2])
ax2 = fig.add_subplot(gs[1])


ax0.set_ylabel("Q8 Training Accuracy", fontsize=16, labelpad=25, weight='bold')
ax0.set_xlabel("Epochs",  fontsize=16, weight='bold')

ax1.yaxis.set_label_position("right")
ax1.set_ylabel(" Q8 Accuracy on CB513",fontsize=16,labelpad=25, weight='bold')

ax2.set_ylabel('ylabel', fontsize=16)
ax2.set_xlabel('Validation', fontsize=13,weight='bold')

ax0.tick_params(labelsize=12)
ax1.tick_params(labelsize=12)
ax2.set_xticks([0,2,4,6,8,10])

ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)


ax1.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)


ax1.spines['right'].set_visible(False)
#ax1.get_xaxis().set_visible(False)

ax0.plot(ticks, color = 'w')
ax1.plot(ticks, color = 'w')
ax2.plot(ticks, color = 'w')


ax0.plot(m5_8['acc'], color='r', label="8 filters", linewidth=3)
plt.plot(m5_8['val_acc'],color='r')

ax0.plot(m5_16['acc'], color='b', label="16 filters", linewidth=3)
plt.plot(m5_16['val_acc'], color='b')


ax0.plot(m5_32['acc'], color='orange', label="32 filters", linewidth=3)
plt.plot(m5_32['val_acc'], color='orange')

ax0.plot(m5_64['acc'], color='g', label="64 filters", linewidth=3)
plt.plot(m5_64['val_acc'], color='g')


ax1.plot(1,m5_8s[1],marker='v', color='r', ls='-',markersize=10)
ax1.plot(2,m5_16s[1],marker='v', color='b', ls='',markersize=10)
ax1.plot(3,m5_32s[1],marker='v', color='orange', ls='',markersize=10)
ax1.plot(4,m5_64s[1],marker='v', color='g', ls='',markersize=10)

res = 0.62
for i in range(13):
    ax0.axhline(y=res, c = "black", linewidth=0.2)
    ax1.axhline(y=res, c = "black", linewidth=0.2)
    ax2.axhline(y=res, c = "black", linewidth=0.2)
    res += 0.01
    

#.legend(loc="upper left")
legend = ax0.legend( title="5 LAYER NETWORK", loc=0, fontsize='large', fancybox=True)
plt.savefig("5 layer network", bbox_inches = 'tight')
plt.show()

# %%
history = pickle.load( open( "newExperiments/guilermo/model_history_1", "rb" ) )

# Plot training & validation accuracy values
plt.plot(history['acc'])
plt.plot(history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
#plt.savefig(accuracyName)
plt.show()


# Plot training & validation loss values
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
#plt.savefig(lossName)
plt.show()
